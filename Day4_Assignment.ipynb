# %% [markdown]
# ### First, to access the data, determine the working directory where your data is located by typing: cd Dropbox/Milestone_Project (in my case) in your terminal

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Import data
Data = pd.read_csv('Value_of_Energy_Cost_Savings_Program_Savings_for_Businesses_-_FY2020.csv')

# %% [markdown]
# ### To explore data little bit

# %%
Data.shape
# Out:
# (450, 26)

# %%
Data.dtypes
# Out:
# Company Name                                  object
# company contact                               object
# company email                                 object
# company phone                                 object
# Address                                       object
# City                                          object
# State                                         object
# Postcode                                       int64
# Industry                                      object
# Industry descr                                object
# Company Type                                  object
# Current fulltime                             float64
# Job created                                  float64
# Job retain                                   float64
# Effective Date                                object
# Total Savings                                float64
# Savings from beginning receiving benefits    float64
# Borough                                       object
# ...

# %%
pd.set_option('display.max_columns', 26)

# %%
Data
# Out:
#                                  Company Name    company contact  \
# 0                              1 State Street      David Neiburg
# 1                              100 Church LLC  Edward A. Carroll
# 2                        100 Wall Investments       Jerry Branam
# 3                 1-10 Bush Terminal Owner LP     Andrew Kimball
# 4    120 Broadway Acquisitions JV, LLC (Ldmk)        Carl Letich
# ..                                        ...                ...
# 445                         WONTON FOOD, INC.         DONALD LAU
# 446                                Wood Works       Gordon Brawm
# 447           WorldWide Plumbing Supply, Inc.    Surie Lefkowitz
# 448                         WUD Furniture LLC     Keren Springer
# 449                       Wurtec Incorporated          Bill Popp
#
#                  company email company phone                Address  \
# 0       eskoblo@energyspec.com    7186779077          1114 Avenue J
# ...

# %% [markdown]
# ### How many different companies are represented in the data set?

# %%
Data['Company Name'].count()
# Out:
# 450

# %% [markdown]
# ### What is the total number of jobs created for businesses in Queens?

# %%
Jobs = Data[Data["Job created"].notna()]

# %%
Jobs2 = Jobs.groupby("City")["Job created"].sum()

# %%
Jobs2
# Out:
# City
# Bronx            19.0
# Brooklyn         25.0
# College Point    12.0
# Queens           90.0
# bronx             3.0
# Name: Job created, dtype: float64

# %% [markdown]
# ## Alternatively:

# %%
Jobs_City = Jobs[["City", "Job created"]]

# %%
Summary = Jobs_City.groupby("City").sum()

# %%
Summary
# Out:
#                Job created
# City
# Bronx                 19.0
# Brooklyn              25.0
# College Point         12.0
# Queens                90.0
# bronx                  3.0

# %% [markdown]
# ### How many different unique email domains names are there in the data set?

# %%
Data["company email"].nunique()
# Out:
# 420

# %% [markdown]
# ### Considering only NTAs with at least 5 listed businesses, what is the average total savings and the total jobs created for each NTA?

# %%
Business1 = Data[['NTA', 'Job created', 'Total Savings']]

# %%
Business1
# Out:
#                                                    NTA  Job created  \
# 0                                              Midwood          NaN
# 1               SoHo-TriBeCa-Civic Center-Little Italy          NaN
# 2                    Battery Park City-Lower Manhattan          NaN
# 3                                     Sunset Park West          NaN
# 4                    Battery Park City-Lower Manhattan          NaN
# ..                                                 ...          ...
# 445                                     Bushwick South         10.0
# 446                                     Bushwick South          NaN
# 447  Mariner's Harbor-Arlington-Port Ivory-Granitev...          NaN
# 448                                Crown Heights North          NaN
# 449                                            Astoria          NaN
#
#      Total Savings
# 0             0.00
# 1        136578.20
# 2        302959.40
# 3          2159.67
# 4        922407.32
# ..             ...
# ...

# %%
# Count the occurrences of each item in the column
item_counts = Business1['NTA'].value_counts()

# %%
# Select items occurring more than 5 times
selected_items = item_counts[item_counts > 5].index

# %%
selected_items
# Out:
# Index(['Hunters Point-Sunnyside-West Maspeth', 'Sunset Park West',
#        'Queensbridge-Ravenswood-Long Island City',
#        'park-cemetery-etc-Brooklyn', 'Greenpoint', 'Mott Haven-Port Morris',
#        'Hunts Point', 'East Williamsburg',
#        'Carroll Gardens-Columbia Street-Red Hook', 'Bushwick South',
#        'DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill', 'East New York',
#        'Maspeth', 'Crown Heights North', 'Manhattanville',
#        'Battery Park City-Lower Manhattan', 'Steinway', 'College Point'],
#       dtype='object')

# %%
# Filter the DataFrame based on selected items
filtered_df = Business1[Business1['NTA'].isin(selected_items)]

# %%
filtered_df
# Out:
#                                                   NTA  Job created  \
# 2                   Battery Park City-Lower Manhattan          NaN
# 3                                    Sunset Park West          NaN
# 4                   Battery Park City-Lower Manhattan          NaN
# 5                   Battery Park City-Lower Manhattan          NaN
# 6                Hunters Point-Sunnyside-West Maspeth          NaN
# ..                                                ...          ...
# 443                                  Sunset Park West          NaN
# 444  DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill          NaN
# 445                                    Bushwick South         10.0
# 446                                    Bushwick South          NaN
# 448                               Crown Heights North          NaN
#
#      Total Savings
# 2        302959.40
# 3          2159.67
# 4        922407.32
# 5        368601.17
# 6          1637.29
# ..             ...
# ...

# %% [markdown]
# ## To check if each category under NTA has more than 5 business

# %%
# Sort the DataFrame by a specific column (e.g., 'Age')
sorted_df = filtered_df.sort_values(by='NTA')

# %%
# Set display options to show full data
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)  # Remove column width restriction

# %%
# Print the full DataFrame
print(sorted_df)
# Out:
#                                                   NTA  Job created  \
# 2                   Battery Park City-Lower Manhattan          NaN
# 4                   Battery Park City-Lower Manhattan          NaN
# 5                   Battery Park City-Lower Manhattan          NaN
# 90                  Battery Park City-Lower Manhattan          NaN
# 110                 Battery Park City-Lower Manhattan          NaN
# 10                  Battery Park City-Lower Manhattan          NaN
# 11                  Battery Park City-Lower Manhattan          NaN
# 299                 Battery Park City-Lower Manhattan          NaN
# 124                 Battery Park City-Lower Manhattan          NaN
# 309                                    Bushwick South          NaN
# 28                                     Bushwick South          NaN
# 446                                    Bushwick South          NaN
# 203                                    Bushwick South          NaN
# ...

# %%
Total_jobs = filtered_df.groupby("NTA")["Job created"].sum()

# %%
Total_jobs
# Out:
# NTA
# Battery Park City-Lower Manhattan                    0.0
# Bushwick South                                      10.0
# Carroll Gardens-Columbia Street-Red Hook             0.0
# College Point                                        2.0
# Crown Heights North                                  0.0
# DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill     0.0
# East New York                                       15.0
# East Williamsburg                                    0.0
# Greenpoint                                           0.0
# Hunters Point-Sunnyside-West Maspeth                 0.0
# Hunts Point                                         12.0
# Manhattanville                                       0.0
# Maspeth                                             10.0
# Mott Haven-Port Morris                              10.0
# Queensbridge-Ravenswood-Long Island City             0.0
# Steinway                                            20.0
# ...

# %%
Avg_saving = filtered_df.groupby("NTA")["Total Savings"].mean()

# %%
Avg_saving
# Out:
# NTA
# Battery Park City-Lower Manhattan                   469890.796667
# Bushwick South                                       26140.455000
# Carroll Gardens-Columbia Street-Red Hook             24337.390000
# College Point                                        17159.372857
# Crown Heights North                                   4036.298889
# DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill     59950.340000
# East New York                                        48433.093333
# East Williamsburg                                    13990.626364
# Greenpoint                                            9753.649286
# Hunters Point-Sunnyside-West Maspeth                 23931.398933
# Hunts Point                                          39246.016154
# Manhattanville                                        2760.888889
# Maspeth                                               6658.283333
# Mott Haven-Port Morris                               17843.937857
# ...

# %% [markdown]
# ### Save your result for the previous question as a CSV file

# %%
Total_jobs.to_csv('Total_jobs.csv',index=True)

# %%
Avg_saving.to_csv('Avg_Income.csv',index=True)
